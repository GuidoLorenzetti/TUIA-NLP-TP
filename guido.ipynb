# %%
from obtener_noticias import *

# %%
noticias = cargar_csv()

# %%
noticias
# Out:
#                                                    url  \
# 0    https://www.infobae.com//economia/2023/10/30/d...
# 1    https://www.infobae.com//economia/2023/10/30/t...
# 2    https://www.infobae.com//economia/2023/10/30/t...
# 3    https://www.infobae.com//economia/2023/10/30/b...
# 4    https://www.infobae.com//economia/2023/10/30/s...
# ..                                                 ...
# 118  https://www.infobae.com//tecno/2023/10/26/por-...
# 119  https://www.infobae.com//tecno/2023/10/26/hono...
# 120  https://www.infobae.com//tecno/2023/10/26/inte...
# 121  https://www.infobae.com//tecno/2023/10/26/como...
# 122  https://www.infobae.com//tecno/2023/10/26/en-v...
#
#                                                 titulo  \
# 0    Dólar hoy en vivo: la cotización libre retroce...
# 1    Tras la implementación de “Compre sin IVA”, cr...
# 2    Turismo de cabotaje: más de medio millón de pe...
# 3    Baja la deuda con el FMI, pero sube mes a mes ...
# ...
